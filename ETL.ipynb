#   1050K .......... .......... .......... .......... .......... 20% 74.9M 0s
#   1100K .......... .......... .......... .......... .......... 21%  165M 0s
#   1150K .......... .......... .......... .......... .......... 22%  174M 0s
#   1200K .......... .......... .......... .......... .......... 23%  174M 0s
#   1250K .......... .......... .......... .......... .......... 24%  129M 0s
#   1300K .......... .......... .......... .......... .......... 25%  160M 0s
#   1350K .......... .......... .......... .......... .......... 26% 58.9M 0s
#   1400K .......... .......... .......... .......... ..

# %%
# %python
localOrderFilePath = "file:/tmp/orders.csv"
localOrderItemFilePath = "file:/tmp/order_items.csv"
localProductFilePath = "file:/tmp/products.csv"
localCategoriesFilePath = "file:/tmp/categories.csv"
localAdventureWorks_ProductsPath = "file:/tmp/AdventureWorks_Products.csv"

dbutils.fs.mkdirs("dbfs:/datasets")
dbutils.fs.cp(localOrderFilePath, "dbfs:/datasets/")#hadoop fs -put * /hdfs
dbutils.fs.cp(localOrderItemFilePath, "dbfs:/datasets")
dbutils.fs.cp(localProductFilePath, "dbfs:/datasets/")
dbutils.fs.cp(localCategoriesFilePath, "dbfs:/datasets")
dbutils.fs.cp(localAdventureWorks_ProductsPath, "dbfs:/datasets")

display(dbutils.fs.ls("dbfs:/datasets"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/datasets/AdventureWorks_Products.csv</td><td>AdventureWorks_Products.csv</td><td>58122</td></tr><tr><td>dbfs:/datasets/categories.csv</td><td>categories.csv</td><td>1029</td></tr><tr><td>dbfs:/datasets/order_items.csv</td><td>order_items.csv</td><td>5408880</td></tr><tr><td>dbfs:/datasets/orders.csv</td><td>orders.csv</td><td>2999944</td></tr><tr><td>dbfs:/datasets/products.csv</td><td>products.csv</td><td>171902</td></tr></tbody></table></div>

# %%
# %python
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
 
spark = (SparkSession
             .builder
             .appName("Retail Data Analysis With SPARK DataFrame")
             .enableHiveSupport()
             .getOrCreate()
            )
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.172.208.32:40001">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[8]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Databricks Shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
ordersDF = spark.read.csv("dbfs:/datasets/orders.csv")
productsDF = spark.read.csv("dbfs:/datasets/products.csv")
orderItemsDF = spark.read.csv("dbfs:/datasets/order_items.csv") 
categoriesDF = spark.read.csv("dbfs:/datasets/categories.csv") 
AdventureWorksProductsDF = spark.read.csv("dbfs:/datasets/AdventureWorks_Products.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ordersSchema  = StructType([
    StructField("OrderID",IntegerType(),True),  
    StructField("OrderDate",DateType(),True),  
    StructField("CustomerID", IntegerType(), True), 
    StructField("OrderStatus", StringType(), True)   
  ])
 
ordersDFWithSchema = (sqlContext.read.format("csv")
   .option("delimiter",",").option("quote","")
  .option("header", "false")
  .schema(ordersSchema)
  .load("dbfs:/datasets/orders.csv"))
 
#ordersDFWithSchema.show()

productsSchema  = StructType([
    StructField("ProductID",IntegerType(),True), 
    StructField("CategoryID",IntegerType(),True), 
    StructField("Descriptione",StringType(),True),  
    StructField("Price", DoubleType(), True), 
    StructField("Image", StringType(), True)   
  ])
 
productsDFWithSchema = (sqlContext.read.format("csv")
   .option("delimiter",",").option("quote","")
  .option("header", "false")
  .schema(productsSchema)
  .load("dbfs:/datasets/products.csv"))
 
#productsDFWithSchema.show()

ordersItemSchema =( StructType([
     StructField("OrderItemID",IntegerType()),
     StructField("OrderID",IntegerType()),
     StructField("ProductID",IntegerType()),
     StructField("Quantity",DoubleType()),
     StructField("Subtotal",DoubleType()),
     StructField("ProductPrice",DoubleType())]
     )
                  )
 
ordersItemDFWithSchema =(sqlContext
                          .read
                          .format("csv")
                          .option("header", "false")
                          .schema(ordersItemSchema)
                          .csv("dbfs:/datasets/order_items.csv")
                         )

categorySchema =( StructType([
     StructField("CategoryID",IntegerType()),
     StructField("CategoryDepartmentID",IntegerType()),
     StructField("CategoryName",StringType())]
     )
                  )
 
categoryDFWithSchema =(sqlContext
                          .read
                          .format("csv")
                          .option("header", "false")
                          .schema(categorySchema)
                          .csv("dbfs:/datasets/categories.csv")
                         )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
ordersDFWithSchema.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+----------+---------------+
# OrderID| OrderDate|CustomerID|    OrderStatus|
# +-------+----------+----------+---------------+
#       1|2013-07-25|     11599|         CLOSED|
#       2|2013-07-25|       256|PENDING_PAYMENT|
#       3|2013-07-25|     12111|       COMPLETE|
#       4|2013-07-25|      8827|         CLOSED|
#       5|2013-07-25|     11318|       COMPLETE|
# +-------+----------+----------+---------------+
# only showing top 5 rows
#
# </div>

# %%
productsDFWithSchema.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----------+--------------------+------+--------------------+
# ProductID|CategoryID|        Descriptione| Price|               Image|
# +---------+----------+--------------------+------+--------------------+
#         1|         2|Quest Q64 10 FT. ...| 59.98|http://images.acm...|
#         2|         2|Under Armour Men&#39;...|129.99|http://images.acm...|
#         3|         2|Under Armour Men&#39;...| 89.99|http://images.acm...|
#         4|         2|Under Armour Men&#39;...| 89.99|http://images.acm...|
#         5|         2|Riddell Youth Rev...|199.99|http://images.acm...|
# +---------+----------+--------------------+------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
ordersItemDFWithSchema.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-------+---------+--------+--------+------------+
# OrderItemID|OrderID|ProductID|Quantity|Subtotal|ProductPrice|
# +-----------+-------+---------+--------+--------+------------+
#           1|      1|      957|     1.0|  299.98|      299.98|
#           2|      2|     1073|     1.0|  199.99|      199.99|
#           3|      2|      502|     5.0|   250.0|        50.0|
#           4|      2|      403|     1.0|  129.99|      129.99|
#           5|      4|      897|     2.0|   49.98|       24.99|
# +-----------+-------+---------+--------+--------+------------+
# only showing top 5 rows
#
# </div>

# %%
# faire la jointure des tables

OrderjoinedDf = ordersDFWithSchema.join(ordersItemDFWithSchema, ["OrderID"], "inner")

ProductjoinedDf = OrderjoinedDf.join(productsDFWithSchema, ["ProductID"], "inner")

fullDF = ProductjoinedDf.join(categoryDFWithSchema, ["CategoryID"], "inner")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fullDF.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+---------+-------+----------+----------+---------------+-----------+--------+--------+------------+--------------------+------+--------------------+--------------------+--------------------+
# CategoryID|ProductID|OrderID| OrderDate|CustomerID|    OrderStatus|OrderItemID|Quantity|Subtotal|ProductPrice|        Descriptione| Price|               Image|CategoryDepartmentID|        CategoryName|
# +----------+---------+-------+----------+----------+---------------+-----------+--------+--------+------------+--------------------+------+--------------------+--------------------+--------------------+
#         43|      957|      1|2013-07-25|     11599|         CLOSED|          1|     1.0|  299.98|      299.98|Diamondback Women...|299.98|http://images.acm...|                   7|    Camping &amp; Hiking|
#         48|     1073|      2|2013-07-25|       256|PENDING_PAYMENT|          2|     1.0|  199.99|      199.99|Pelican Sunstream...|199.99|http://images.acm...|                   7|        Water Sports|
#         24|      502|      2|2013-07-25|       256|PENDING_PAYMENT|          3|     5.0|   250.0|        50.0|Nike Men&#39;s Dri-FI...|  50.0|http://images.acm...|                   5|     Women&#39;s Apparel|
#         18|      403|      2|2013-07-25|       256|PENDING_PAYMENT|          4|     1.0|  129.99|      129.99|Nike Men&#39;s CJ Eli...|129.99|http://images.acm...|                   4|      Men&#39;s Footwear|
#         40|      897|      4|2013-07-25|      8827|         CLOSED|          5|     2.0|   49.98|       24.99|Team Golf New Eng...| 24.99|http://images.acm...|                   6|         Accessories|
#         17|      365|      4|2013-07-25|      8827|         CLOSED|          6|     5.0|  299.95|       59.99|Perfect Fitness P...| 59.99|http://images.acm...|                   4|              Cleats|
#         24|      502|      4|2013-07-25|      8827|         CLOSED|          7|     3.0|   150.0|        50.0|Nike Men&#39;s Dri-FI...|  50.0|http://images.acm...|                   5|     Women&#39;s Apparel|
#         46|     1014|      4|2013-07-25|      8827|         CLOSED|          8|     4.0|  199.92|       49.98|O&#39;Brien Men&#39;s Neo...| 49.98|http://images.acm...|                   7|Indoor/Outdoor Games|
#         43|      957|      5|2013-07-25|     11318|       COMPLETE|          9|     1.0|  299.98|      299.98|Diamondback Women...|299.98|http://images.acm...|                   7|    Camping &amp; Hiking|
#         17|      365|      5|2013-07-25|     11318|       COMPLETE|         10|     5.0|  299.95|       59.99|Perfect Fitness P...| 59.99|http://images.acm...|                   4|              Cleats|
#         46|     1014|      5|2013-07-25|     11318|       COMPLETE|         11|     2.0|   99.96|       49.98|O&#39;Brien Men&#39;s Neo...| 49.98|http://images.acm...|                   7|Indoor/Outdoor Games|
#         43|      957|      5|2013-07-25|     11318|       COMPLETE|         12|     1.0|  299.98|      299.98|Diamondback Women...|299.98|http://images.acm...|                   7|    Camping &amp; Hiking|
#         18|      403|      5|2013-07-25|     11318|       COMPLETE|         13|     1.0|  129.99|      129.99|Nike Men&#39;s CJ Eli...|129.99|http://images.acm...|                   4|      Men&#39;s Footwear|
#         48|     1073|      7|2013-07-25|      4530|       COMPLETE|         14|     1.0|  199.99|      199.99|Pelican Sunstream...|199.99|http://images.acm...|                   7|        Water Sports|
#         43|      957|      7|2013-07-25|      4530|       COMPLETE|         15|     1.0|  299.98|      299.98|Diamondback Women...|299.98|http://images.acm...|                   7|    Camping &amp; Hiking|
#         41|      926|      7|2013-07-25|      4530|       COMPLETE|         16|     5.0|   79.95|       15.99|Glove It Imperial...| 15.99|http://images.acm...|                   6|            Trade-In|
#         17|      365|      8|2013-07-25|      2911|     PROCESSING|         17|     3.0|  179.97|       59.99|Perfect Fitness P...| 59.99|http://images.acm...|                   4|              Cleats|
#         17|      365|      8|2013-07-25|      2911|     PROCESSING|         18|     5.0|  299.95|       59.99|Perfect Fitness P...| 59.99|http://images.acm...|                   4|              Cleats|
#         46|     1014|      8|2013-07-25|      2911|     PROCESSING|         19|     4.0|  199.92|       49.98|O&#39;Brien Men&#39;s Neo...| 49.98|http://images.acm...|                   7|Indoor/Outdoor Games|
#         24|      502|      8|2013-07-25|      2911|     PROCESSING|         20|     1.0|    50.0|        50.0|Nike Men&#39;s Dri-FI...|  50.0|http://images.acm...|                   5|     Women&#39;s Apparel|
# +----------+---------+-------+----------+----------+---------------+-----------+--------+--------+------------+--------------------+------+--------------------+--------------------+--------------------+
# only showing top 20 rows
#
# </div>

# %%
# nb total de commande , revenue, ... groupby customerID

CustomerSummary =(ProductjoinedDf.select(
  col("CustomerID")
, col("Quantity")
, col("ProductPrice")
, col("OrderDate")
).groupBy("CustomerID")
  .agg(
      sum("Quantity").alias("Total Orders"),
      sum("ProductPrice").alias("Total Revenue"),
      avg("ProductPrice").alias("Avg Order Revenue"),
      max("OrderDate").alias("Last Order Date")
  )     
)

   
CustomerSummary.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+------------+------------------+------------------+---------------+
# CustomerID|Total Orders|     Total Revenue| Avg Order Revenue|Last Order Date|
# +----------+------------+------------------+------------------+---------------+
#        833|        22.0|1938.8500000000001|176.25909090909093|     2014-03-20|
#       1088|        22.0|            1429.9|119.15833333333335|     2014-02-05|
#       6397|        49.0|3043.6900000000005|144.93761904761908|     2014-06-23|
#      11033|        12.0|            934.94|           186.988|     2014-03-27|
#       8389|        16.0|1899.8700000000001| 211.0966666666667|     2014-05-11|
#      12046|        13.0|            869.95|144.99166666666667|     2014-05-08|
#       4900|        17.0|           2109.83|191.80272727272725|     2014-05-01|
#       6357|        25.0|           3249.76| 191.1623529411765|     2014-07-22|
#       3175|        43.0|           2059.79|            108.41|     2014-04-18|
#       1959|        29.0|1234.8700000000001| 112.2609090909091|     2014-07-07|
#      11748|        29.0|           3239.79|179.98833333333334|     2014-02-22|
#       9900|         4.0|            999.94|           249.985|     2013-08-06|
#       9376|        33.0|            2454.8| 136.3777777777778|     2014-05-13|
#       7554|        27.0|           1774.88|147.90666666666667|     2014-05-31|
#       4935|        38.0|1986.8000000000002|104.56842105263159|     2014-06-23|
#       8592|        26.0|           2494.78|166.31866666666667|     2014-05-21|
#       5803|        84.0|4064.6099999999997|127.01906249999999|     2014-07-22|
#       5156|        22.0|           1434.88|119.57333333333334|     2014-07-07|
#       7253|         9.0| 709.9000000000001|118.31666666666668|     2014-01-01|
#       4101|        44.0|1904.8500000000001|119.05312500000001|     2014-02-19|
# +----------+------------+------------------+------------------+---------------+
# only showing top 20 rows
#
# </div>

# %%
# nb total de commande , revenue, ... groupby customerID

ProductSummary =(fullDF.select(
  col("ProductID")
#, col("CategoryID")
#, col("CategoryName")
, col("Quantity")
, col("ProductPrice")
, col("Price")
 #.groupBy("ProductID", "CategoryID", "CategoryName")
 ).groupBy("ProductID")
  .agg(
      sum("Quantity").alias("Total Quantity"),
      sum("ProductPrice").alias("Total Revenue"),
      avg("ProductPrice").alias("Avg Order Revenue"),
      avg("Quantity").alias("Avg Quantity"),
      avg(col("ProductPrice")-col("ProductPrice")*0.30).alias("Avg Discount"),
      avg("Price").alias("Avg Price")
  )     
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

CustomerSummary.createGlobalTempView("CustomerSummary") 
sqlCustomerSummary = spark.sql("SELECT * FROM global_temp.CustomerSummary")

ProductSummary.createGlobalTempView("ProductSummary") 
sqlProductSummary = spark.sql("SELECT * FROM global_temp.ProductSummary")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-4157112540666371&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>CustomerSummary<span class="ansi-blue-fg">.</span>createGlobalTempView<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;CustomerSummary&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> sqlCustomerSummary <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;SELECT * FROM global_temp.CustomerSummary&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> ProductSummary<span class="ansi-blue-fg">.</span>createGlobalTempView<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;ProductSummary&#34;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> sqlProductSummary <span class="ansi-blue-fg">=</span> spark<span class="ansi-blue-fg">.</span>sql<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;SELECT * FROM global_temp.ProductSummary&#34;</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansi-cyan-fg">createGlobalTempView</span><span class="ansi-blue-fg">(self, name)</span>
# <span class="ansi-green-intense-fg ansi-bold">    202</span>
# <span class="ansi-green-intense-fg ansi-bold">    203</span>         &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 204</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jdf<span class="ansi-blue-fg">.</span>createGlobalTempView<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    205</span>
# <span class="ansi-green-intense-fg ansi-bold">    206</span>     <span class="ansi-blue-fg">@</span>since<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">2.2</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1304</span>         return_value = get_return_value(
# <span class="ansi-green-fg">-&gt; 1305</span><span class="ansi-red-fg">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansi-green-intense-fg ansi-bold">   1306</span>
# <span class="ansi-green-intense-fg ansi-bold">   1307</span>         <span class="ansi-green-fg">for</span> temp_arg <span class="ansi-green-fg">in</span> temp_args<span class="ansi-blue-fg">:</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    131</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    132</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 133</span><span class="ansi-red-fg">                 </span>raise_from<span class="ansi-blue-fg">(</span>converted<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    134</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    135</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">raise_from</span><span class="ansi-blue-fg">(e)</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Temporary view &#39;customersummary&#39; already exists;</div>

# %%
fullDF.createGlobalTempView("fullDF") 
sqlfullDF = spark.sql("SELECT * FROM global_temp.fullDF")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
